# %%
import pandas as pd
import matplotlib.pyplot as plt
file_name = "reviews.csv" #load company review database
reviews = pd.read_csv(file_name, sep=',') #read data

# %%
reviews.head(5)#print first 5 data
# Out:
#    Unnamed: 0 company           location          dates  \
# 0           1  google               none   Dec 11, 2018
# 1           2  google  Mountain View, CA   Jun 21, 2013
# 2           3  google       New York, NY   May 10, 2014
# 3           4  google  Mountain View, CA    Feb 8, 2015
# 4           5  google    Los Angeles, CA   Jul 19, 2018
#
#                                   job-title  \
# 0     Current Employee - Anonymous Employee
# 1         Former Employee - Program Manager
# 2  Current Employee - Software Engineer III
# 3     Current Employee - Anonymous Employee
# 4       Former Employee - Software Engineer
#
#                                              summary  \
# 0                           Best Company to work for
# 1  Moving at the speed of light, burn out is inev...
# 2  Great balance between big-company security and...
# 3  The best place I've worked and also the most d...
# 4                    Unique, one of a kind dream job
#
# ...

# %%
print(reviews['company'][50000])#check data correctly working
# Out:
# microsoft

# %%
#fileting each company name
google=0
netflix=0
amazon=0
facebook=0
microsoft=0
apple=0
for i in range(1,979319):
    try:
        
        if reviews['company'][i]=="google":
            google += reviews['helpful-count'][i]
        elif reviews['company'][i]=="amazon":
            amazon += reviews['helpful-count'][i]
        elif reviews['company'][i]=="netflix":
            netflix += reviews['helpful-count'][i]
        elif reviews['company'][i]=="facebook":
            facebook += reviews['helpful-count'][i]
        elif reviews['company'][i]=="microsoft":
            microsoft += reviews['helpful-count'][i]
        elif reviews['company'][i]=="apple":
            apple += reviews['helpful-count'][i]
          
    except: 
        x="go back"

# %%
#plot for number of reviews count
import numpy as np
import matplotlib.pyplot as plt

# define some sizes of the scatter marker

fig, ax = plt.subplots()


ax.scatter("google", google, facecolor='yellow', label='google')
ax.scatter("netflix", netflix, facecolor='green', label='netflix')
ax.scatter("amazon", amazon, facecolor='red', label='amazon')
ax.scatter("facebook", facebook, facecolor='black', label='facebook')
ax.scatter("microsoft", microsoft, facecolor='gray', label='microsoft')
ax.scatter("apple", apple, facecolor='pink', label='apple')
plt.legend(('google', 'netflix', 'amazon', 'facebook','microsoft','apple'))

plt.show()

# %%
#fileting each company name
google=[]
netflix=[]
amazon=[]
facebook=[]
microsoft=[]
apple=[]
for i in range(1,50000):
    try:    
        if reviews['company'][i]=="google":
            google.append(reviews['overall-ratings'][i])
        elif reviews['company'][i]=="amazon":
            amazon.append(reviews['overall-ratings'][i])
        elif reviews['company'][i]=="netflix":
            netflix.append(reviews['overall-ratings'][i])
        elif reviews['company'][i]=="facebook":
            facebook.append(reviews['overall-ratings'][i])
        elif reviews['company'][i]=="microsoft":
            microsoft.append(reviews['overall-ratings'][i])
        elif reviews['company'][i]=="apple":
            apple.append(reviews['overall-ratings'][i])
          
    except: 
        x="go back"

# %%
import numpy as np
print(np.average(google))
print(np.average(amazon))
print(np.average(netflix))
print(np.average(facebook))
print(np.average(microsoft))
print(np.average(apple))
# Out:
# 4.3393451010488615
# 3.587362845251608
# 3.411111111111111
# 4.511949685534591
# 4.144638403990025
# 3.9582239382239384

# %%
#plot for overall-ratings
import numpy as np
import matplotlib.pyplot as plt

# define some sizes of the scatter marker

fig, ax = plt.subplots()


ax.scatter("google", np.average(google), facecolor='yellow', label='google')
ax.scatter("netflix", np.average(netflix), facecolor='green', label='netflix')
ax.scatter("amazon", np.average(amazon), facecolor='red', label='amazon')
ax.scatter("facebook", np.average(facebook), facecolor='black', label='facebook')
ax.scatter("microsoft", np.average(microsoft), facecolor='gray', label='microsoft')
ax.scatter("apple", np.average(apple), facecolor='pink', label='apple')
plt.legend(('google', 'netflix', 'amazon', 'facebook','microsoft','apple'))

plt.show()

# %%
#fileting each company name then count work-balance-stars
google=[]
netflix=[]
amazon=[]
facebook=[]
microsoft=[]
apple=[]
for i in range(1,90319):
    try:
        
        if reviews['company'][i]=="google":
            if reviews['work-balance-stars'][i]!="none":
                google.append(int(float(reviews['work-balance-stars'][i])))
        elif reviews['company'][i]=="amazon":
            if reviews['work-balance-stars'][i]!="none":
                amazon.append(int(float(reviews['work-balance-stars'][i])))
        elif reviews['company'][i]=="netflix":
            if reviews['work-balance-stars'][i]!="none":
                netflix.append(int(float(reviews['work-balance-stars'][i])))
        elif reviews['company'][i]=="facebook":
            if reviews['work-balance-stars'][i]!="none":
                facebook.append(int(float(reviews['work-balance-stars'][i])))
        elif reviews['company'][i]=="microsoft":
            if reviews['work-balance-stars'][i]!="none":
                microsoft.append(int(float(reviews['work-balance-stars'][i])))
        elif reviews['company'][i]=="apple":
            if reviews['work-balance-stars'][i]!="none":
                apple.append(int(float(reviews['work-balance-stars'][i])))
          
    except: 
        x="go back"

# %%
import numpy as np
print(np.average(google))
print(np.average(amazon))
print(np.average(netflix))
print(np.average(facebook))
print(np.average(microsoft))
print(np.average(apple))
# Out:
# 3.980049109883364
# 3.0063108852181277
# 3.211842105263158
# 3.9200515796260476
# 3.571834115033325
# 3.3478297944913447

# %%
#plot for work-balance-stars
import numpy as np
import matplotlib.pyplot as plt

# define some sizes of the scatter marker

fig, ax = plt.subplots()


ax.scatter("google", np.average(google), facecolor='yellow', label='google')
ax.scatter("netflix", np.average(netflix), facecolor='green', label='netflix')
ax.scatter("amazon", np.average(amazon), facecolor='red', label='amazon')
ax.scatter("facebook", np.average(facebook), facecolor='black', label='facebook')
ax.scatter("microsoft", np.average(microsoft), facecolor='gray', label='microsoft')
ax.scatter("apple", np.average(apple), facecolor='pink', label='apple')
plt.legend(('google', 'netflix', 'amazon', 'facebook','microsoft','apple'))

plt.show()

# %%
#fileting each company name then count culture-values-stars
google=[]
netflix=[]
amazon=[]
facebook=[]
microsoft=[]
apple=[]
for i in range(1,90319):
    try:
        
        if reviews['company'][i]=="google":
            if reviews['culture-values-stars'][i]!="none":
                google.append(int(float(reviews['culture-values-stars'][i])))
        elif reviews['company'][i]=="amazon":
            if reviews['culture-values-stars'][i]!="none":
                amazon.append(int(float(reviews['culture-values-stars'][i])))
        elif reviews['company'][i]=="netflix":
            if reviews['culture-values-stars'][i]!="none":
                netflix.append(int(float(reviews['culture-values-stars'][i])))
        elif reviews['company'][i]=="facebook":
            if reviews['culture-values-stars'][i]!="none":
                facebook.append(int(float(reviews['culture-values-stars'][i])))
        elif reviews['company'][i]=="microsoft":
            if reviews['culture-values-stars'][i]!="none":
                microsoft.append(int(float(reviews['culture-values-stars'][i])))
        elif reviews['company'][i]=="apple":
            if reviews['culture-values-stars'][i]!="none":
                apple.append(int(float(reviews['culture-values-stars'][i])))
          
    except: 
        x="go back"

# %%
#plot for culture-values-stars
import numpy as np
import matplotlib.pyplot as plt

# define some sizes of the scatter marker

fig, ax = plt.subplots()


ax.scatter("google", np.average(google), facecolor='yellow', label='google')
ax.scatter("netflix", np.average(netflix), facecolor='green', label='netflix')
ax.scatter("amazon", np.average(amazon), facecolor='red', label='amazon')
ax.scatter("facebook", np.average(facebook), facecolor='black', label='facebook')
ax.scatter("microsoft", np.average(microsoft), facecolor='gray', label='microsoft')
ax.scatter("apple", np.average(apple), facecolor='pink', label='apple')
plt.legend(('google', 'netflix', 'amazon', 'facebook','microsoft','apple'))

plt.show()

# %%
#fileting each company name then count culture-values-stars
google=[]
netflix=[]
amazon=[]
facebook=[]
microsoft=[]
apple=[]
for i in range(1,90319):
    try:
        
        if reviews['company'][i]=="google":
            if reviews['carrer-opportunities-stars'][i]!="none":
                google.append(int(float(reviews['carrer-opportunities-stars'][i])))
        elif reviews['company'][i]=="amazon":
            if reviews['carrer-opportunities-stars'][i]!="none":
                amazon.append(int(float(reviews['carrer-opportunities-stars'][i])))
        elif reviews['company'][i]=="netflix":
            if reviews['carrer-opportunities-stars'][i]!="none":
                netflix.append(int(float(reviews['carrer-opportunities-stars'][i])))
        elif reviews['company'][i]=="facebook":
            if reviews['carrer-opportunities-stars'][i]!="none":
                facebook.append(int(float(reviews['carrer-opportunities-stars'][i])))
        elif reviews['company'][i]=="microsoft":
            if reviews['carrer-opportunities-stars'][i]!="none":
                microsoft.append(int(float(reviews['carrer-opportunities-stars'][i])))
        elif reviews['company'][i]=="apple":
            if reviews['carrer-opportunities-stars'][i]!="none":
                apple.append(int(float(reviews['carrer-opportunities-stars'][i])))
          
    except: 
        x="go back"

# %%
#plot for carrer-opportunities-stars
import numpy as np
import matplotlib.pyplot as plt

# define some sizes of the scatter marker

fig, ax = plt.subplots()


ax.scatter("google", np.average(google), facecolor='yellow', label='google')
ax.scatter("netflix", np.average(netflix), facecolor='green', label='netflix')
ax.scatter("amazon", np.average(amazon), facecolor='red', label='amazon')
ax.scatter("facebook", np.average(facebook), facecolor='black', label='facebook')
ax.scatter("microsoft", np.average(microsoft), facecolor='gray', label='microsoft')
ax.scatter("apple", np.average(apple), facecolor='pink', label='apple')
plt.legend(('google', 'netflix', 'amazon', 'facebook','microsoft','apple'))

plt.show()

# %%
#fileting each company name then count comp-benefit-stars
google=[]
netflix=[]
amazon=[]
facebook=[]
microsoft=[]
apple=[]
for i in range(1,90319):
    try:
        
        if reviews['company'][i]=="google":
            if reviews['comp-benefit-stars'][i]!="none":
                google.append(int(float(reviews['comp-benefit-stars'][i])))
        elif reviews['company'][i]=="amazon":
            if reviews['comp-benefit-stars'][i]!="none":
                amazon.append(int(float(reviews['comp-benefit-stars'][i])))
        elif reviews['company'][i]=="netflix":
            if reviews['comp-benefit-stars'][i]!="none":
                netflix.append(int(float(reviews['comp-benefit-stars'][i])))
        elif reviews['company'][i]=="facebook":
            if reviews['comp-benefit-stars'][i]!="none":
                facebook.append(int(float(reviews['comp-benefit-stars'][i])))
        elif reviews['company'][i]=="microsoft":
            if reviews['comp-benefit-stars'][i]!="none":
                microsoft.append(int(float(reviews['comp-benefit-stars'][i])))
        elif reviews['company'][i]=="apple":
            if reviews['comp-benefit-stars'][i]!="none":
                apple.append(int(float(reviews['comp-benefit-stars'][i])))
          
    except: 
        x="go back"

# %%
#plot for comp-benefit-stars
import numpy as np
import matplotlib.pyplot as plt

# define some sizes of the scatter marker

fig, ax = plt.subplots()


ax.scatter("google", np.average(google), facecolor='yellow', label='google')
ax.scatter("netflix", np.average(netflix), facecolor='green', label='netflix')
ax.scatter("amazon", np.average(amazon), facecolor='red', label='amazon')
ax.scatter("facebook", np.average(facebook), facecolor='black', label='facebook')
ax.scatter("microsoft", np.average(microsoft), facecolor='gray', label='microsoft')
ax.scatter("apple", np.average(apple), facecolor='pink', label='apple')
plt.legend(('google', 'netflix', 'amazon', 'facebook','microsoft','apple'))

plt.show()
